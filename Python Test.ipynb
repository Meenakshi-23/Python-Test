# %%
import pandas as pd

# %%
df= pd.read_csv(r"C:\Users\hello\Downloads\Sample_Input.csv")

# %%
df.head()
# Out:
#            ItemId ComputerId ItemName Comment Unit C/S/ID DataType BitPos  \
# 12766  06-05-2022   21:59:36      870       0    0      0        0      0
# 12767  06-05-2022   21:59:36      875       0    0      0        0      0
# 12768  06-05-2022   21:59:36      880       0    0      0        0      0
# 12769  06-05-2022   21:59:36      885       0    0      0        0      0
# 12770  06-05-2022   21:59:36      890       0    0      0        0      0
#
#       Address MAX  ...    ScaleMin Decimal Unnamed: 14 Unnamed: 15  \
# 12766       0   0  ...  194.412003       0           0           0
# 12767       0   0  ...  194.412003       0           0           0
# 12768       0   0  ...  194.412003       0           0           0
# 12769       0   0  ...  194.412003       0           0           0
# 12770       0   0  ...  194.412003       0           0           0
#
#       Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21
# ...

# %%
df.shape
# Out:
# (12771, 22)

# %%
df1=df.iloc[0:19]

# %%
df1.tail()
# Out:
#    ItemId ComputerId          ItemName                           Comment Unit  \
# 14  83536         10  L_R1SD_DS_SPDFBK  R1 SCREW DOWN DS SPEED FBK (MPS)  NaN
# 15  83537         10   L_R1SDLS_SPDFBK  R1 SCREW DOWN LS SPEED FBK (MPS)  NaN
# 16  83538         10     L_R1SD_WS_CUR      R1 SCREW DOWN WS CURRENT (%)  NaN
# 17  83539         10     L_R1SD_DS_CUR      R1 SCREW DOWN DS CURRENT (%)  NaN
# 18  83540         10    L_R1_CNT_PASS0              R1 CONTROL PASS ZERO  NaN
#
#    C/S/ID                     DataType BitPos  Address    MAX  ... ScaleMin  \
# 14      0                 REAL : Float      0  0x16474  10000  ...   -10000
# 15      0                 REAL : Float      0  0x16478  10000  ...   -10000
# 16      0  INT : Signed 2 Byte Integer      0  0x2bb58  32767  ...   -32768
# 17      0  INT : Signed 2 Byte Integer      0  0x2bb5a  32767  ...   -32768
# 18      0              BOOL : Bit Data      2  0x166b4      1  ...        0
#
# ...

# %%
df1.columns
# Out:
# Index(['ItemId', 'ComputerId', 'ItemName', 'Comment', 'Unit', 'C/S/ID',
#        'DataType', 'BitPos', 'Address', 'MAX', 'MIN', 'ScaleMax', 'ScaleMin',
#        'Decimal', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21'],
#       dtype='object')

# %%
data_df1=df1.drop(['Unit','C/S/ID','ComputerId',
       'DataType', 'BitPos', 'Address', 'MAX', 'MIN', 'ScaleMax', 'ScaleMin',
       'Decimal', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
       'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21'],axis=1)

# %%
data_df1.rename(columns={'ItemId':'tag_id'}, inplace='True')
print(data_df1)
# Out:
#    tag_id           ItemName                                 Comment
# 0   35827     L_R1SDW_SPDREF  R1 Screw Down WS Speed Reference (mps)
# 1   35828     L_R1SDD_SPDREF  R1 Screw Down DS Speed Reference (mps)
# 2   35829     L_R1SDL_SPDREF  R1 Screw Down LS Speed Reference (mps)
# 3   35830     L_R1SDW_SPDFBK   R1 Screw Down WS Speed Feedback (mps)
# 4   35831     L_R1SDD_SPDFBK   R1 Screw Down DS Speed Feedback (mps)
# 5   35832     L_R1SDL_SPDFBK   R1 Screw Down LS Speed Feedback (mps)
# 6   35974   L_R1_ODG_AUX_B07                   R1 ODG AUX output B07
# 7   83528  RM1_RUNDOWN_ID_HS                           R! RUNDOWN ID
# 8   83530      L_R1SD_WS_GAP        R1 SCREW DOWN WORK SIDE GAP (MM)
# 9   83531      L_R1SD_DS_GAP       R1 SCREW DOWN DRIVE SIDE GAP (MM)
# 10  83532   L_R1SD_WS_SPDREF          R1 SCREW DOWN WS SPD REF (MPS)
# 11  83533   L_R1SD_DS_SPDREF          R1 SCREW DOWN DS SPD REF (MPS)
# 12  83534    L_R1SDLS_SPDREF       R1 SCREW DOWN LOW SPEED REF (MPS)
# ...

# %%
df2= df.iloc[19:]

# %%
df2.head()
# Out:
#         ItemId ComputerId   ItemName         Comment            Unit  \
# 19        Date       Time  Milli Sec  L_R1SDW_SPDREF  L_R1SDD_SPDREF
# 20  06-05-2022   21:58:33        140               0               0
# 21  06-05-2022   21:58:33        145               0               0
# 22  06-05-2022   21:58:33        150               0               0
# 23  06-05-2022   21:58:33        155               0               0
#
#             C/S/ID        DataType          BitPos         Address  \
# 19  L_R1SDL_SPDREF  L_R1SDW_SPDFBK  L_R1SDD_SPDFBK  L_R1SDL_SPDFBK
# 20               0               0               0               0
# 21               0               0               0               0
# 22               0               0               0               0
# 23               0               0               0               0
#
#                  MAX  ...       ScaleMin           Decimal       Unnamed: 14  \
# ...

# %%
df2.columns
# Out:
# Index(['ItemId', 'ComputerId', 'ItemName', 'Comment', 'Unit', 'C/S/ID',
#        'DataType', 'BitPos', 'Address', 'MAX', 'MIN', 'ScaleMax', 'ScaleMin',
#        'Decimal', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21'],
#       dtype='object')

# %%
data_df2= df2.groupby(['ItemId','ComputerId', 'ItemName', 'Comment', 'Unit', 'C/S/ID',
       'DataType', 'BitPos', 'Address', 'MAX', 'MIN', 'ScaleMax', 'ScaleMin',
       'Decimal', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
       'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21']).max()

# %%
data_df2
# Out:
# Empty DataFrame
# Columns: []
# ...
